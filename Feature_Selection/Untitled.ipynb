# %% [markdown]
# ### Feature-Selection
#
# **Retrieval the important features, selecting an important features is very important step before going to ML**
#
# - Droping the constant features (Regression and classification)
#
# - Information gain (Classification)
#
# - p-value (Regression)
#
# - VIF (Regression)
#
# - Forward selection and backward selection (Regression and classification)
#
# - Correlation with target column (Regression and classification)
#
#
# **Feature selection methods**
#
# 1. **Variance threshold:**
#
# - based on variance we can decide the data is constant or varying
#
# - Data is not varying much means, data has same values
#
# - For example we have seen in load dataset, loan tearm:360
#
# - Python by default will use variance=0, it will drop these features which are having variance=0
#
# - variance threshold is hyperparameter, we can keep threshold as any value
#
# - based on internal team discussion
#
# - we will drop those features which are having <=threshold value
#
# 2. **P-Value:**
#
# - H0: there is no relation x and y
#
# - H1: There is relation X and Y
#
# - p<0.05
#     - Reject the Null HYPOTHESIS: **Which means include the variable**
# - p>0.05
#     - Not reject the Null Hypothesis: **Which means do not include the variables**
#
# 3. **Mutual info classify:**
#
# - KNN and Entropy
# - It will give the relation between input and output will pick which are having more relation
# - input vs output
#     - A. Entropy
#     - B. KNN
#     - C. R-Squared: Explainability about Y based on X
#
# 4. Forward selection and backward selection
#
# - **Forward selection method**
#     - Start with empty set of failures
#     - iterate through each feature and select the one feature that improves model performance
#     - continue adding features one by one till we meet our criteria
# - **Backward selection project**
#     - Start with full set of features
#     - Iterate through each feature by removing the feature which is having less imapact on the model
#     - Continue the process, till your performance is stable
#
# - Both forward selection and Backward selection methods are complex in nature
# - More time taken, will avoid in general
#
# 5. **Variance Inflation Factor (VIF):**
#    - VIF will give the analysis of multicollinearity
#    - in VIF we will find the R-Squared value of each input feature wrt to other input feature
#    - will keep one feature as input and other feature are consider as output in Regression Equation
#    - This will keep on iterate through all feature
#    - Every feature behaves as input as well as output
#    - as we know wvey regression line give Rsquare value form thta value will find VIF
#    - will drop the feature which are having VIF>5 and VIF>10 based on internal team discussion

# %% [markdown]
# # Variance threshold:

# %%
import pandas as pd
dict1={'A':[100,200,300,400],
       'B':[1,2,3,4],
       'C':[10,20,30,40],
       'D':[10,10,10,10]  
}
df=pd.DataFrame(dict1)
df
# Out:
#      A  B   C   D
# 0  100  1  10  10
# 1  200  2  20  10
# 2  300  3  30  10
# 3  400  4  40  10

# %%
import numpy as np 
np.var(df['A']),np.var(df['B']),np.var(df['C']),np.var(df['D'])
# Out:
# (12500.0, 1.25, 125.0, 0.0)

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
vt=VarianceThreshold(threshold=0)
vt.fit(df)
# Out:
# VarianceThreshold(threshold=0)

# %%
dir(vt)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_support_mask',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
# ...

# %%
vt.feature_names_in_
# Out:
# array(['A', 'B', 'C', 'D'], dtype=object)

# %%
vt.get_feature_names_out()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
vt.fit(df)
# Out:
# VarianceThreshold(threshold=0)

# %%
vt.fit_transform(df)
# Out:
# array([[100,   1,  10],
#        [200,   2,  20],
#        [300,   3,  30],
#        [400,   4,  40]], dtype=int64)

# %%
vt.get_params()
# Out:
# {'threshold': 0}

# %%
vt.get_support()
# Out:
# array([ True,  True,  True, False])

# %%
new_df=df[vt.get_feature_names_out()]
new_df
# Out:
#      A  B   C
# 0  100  1  10
# 1  200  2  20
# 2  300  3  30
# 3  400  4  40

# %%
path=r"C:\Users\Hp\Documents\NareshIT\Data_Files\winequality_red.csv"

# %%
df=pd.read_csv(path)

# %%
X=df.drop('quality',axis=1)

# %%
y=df['quality']

# %%
X[:2]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol
# 0      9.4
# 1      9.8

# %%
y[:2]
# Out:
# 0    5
# 1    5
# Name: quality, dtype: int64

# %%
vt=VarianceThreshold(threshold=0)
vt.fit(X)
# Out:
# VarianceThreshold(threshold=0)

# %%
first=vt.get_feature_names_out()

# %%
vt=VarianceThreshold(threshold=1)
vt.fit(X)
# Out:
# VarianceThreshold(threshold=1)

# %%
second=vt.get_feature_names_out()

# %%
vt=VarianceThreshold(threshold=1.5)
vt.fit(X)
# Out:
# VarianceThreshold(threshold=1.5)

# %%
third=vt.get_feature_names_out()

# %%
len(first),len(second),len(third)
# Out:
# (4, 5, 4)

# %%
first
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol'],
#       dtype=object)

# %%
second
# Out:
# array(['fixed acidity', 'residual sugar', 'free sulfur dioxide',
#        'total sulfur dioxide', 'alcohol'], dtype=object)

# %%
third
# Out:
# array(['fixed acidity', 'residual sugar', 'free sulfur dioxide',
#        'total sulfur dioxide'], dtype=object)

# %% [markdown]
# # Mutual info classify

# %%
path=r"C:\Users\Hp\Documents\NareshIT\Data_Files\winequality_red.csv"

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
X=df.drop('quality',axis=1)

# %%
y=df['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mi=mutual_info_classif(X,y)

# %%
mi
# Out:
# array([0.05261426, 0.11919829, 0.02385147, 0.00957652, 0.0289839 ,
#        0.03806147, 0.08295479, 0.09845927, 0.01044035, 0.10225974,
#        0.1813059 ])

# %%
d=pd.DataFrame(mi,index=X.columns,columns=['mi'])

# %%
d.sort_values(by='mi',ascending=False)*100
# Out:
#                              mi
# alcohol               18.130590
# volatile acidity      11.919829
# sulphates             10.225974
# density                9.845927
# total sulfur dioxide   8.295479
# fixed acidity          5.261426
# free sulfur dioxide    3.806147
# chlorides              2.898390
# citric acid            2.385147
# pH                     1.044035
# residual sugar         0.957652

# %%
final_cols=d.sort_values(by='mi',ascending=False).index[:5]

# %%
X[final_cols]
# Out:
#       alcohol  volatile acidity  sulphates  density  total sulfur dioxide
# 0         9.4             0.700       0.56  0.99780                  34.0
# 1         9.8             0.880       0.68  0.99680                  67.0
# 2         9.8             0.760       0.65  0.99700                  54.0
# 3         9.8             0.280       0.58  0.99800                  60.0
# 4         9.4             0.700       0.56  0.99780                  34.0
# ...       ...               ...        ...      ...                   ...
# 1594     10.5             0.600       0.58  0.99490                  44.0
# 1595     11.2             0.550       0.76  0.99512                  51.0
# 1596     11.0             0.510       0.75  0.99574                  40.0
# 1597     10.2             0.645       0.71  0.99547                  44.0
# 1598     11.0             0.310       0.66  0.99549                  42.0
#
# [1599 rows x 5 columns]

# %%
new_df=pd.DataFrame()
new_df=X[final_cols].copy()

# %%
new_df['quality']=y

# %%
new_df
# Out:
#       alcohol  volatile acidity  sulphates  density  total sulfur dioxide  \
# 0         9.4             0.700       0.56  0.99780                  34.0
# 1         9.8             0.880       0.68  0.99680                  67.0
# 2         9.8             0.760       0.65  0.99700                  54.0
# 3         9.8             0.280       0.58  0.99800                  60.0
# 4         9.4             0.700       0.56  0.99780                  34.0
# ...       ...               ...        ...      ...                   ...
# 1594     10.5             0.600       0.58  0.99490                  44.0
# 1595     11.2             0.550       0.76  0.99512                  51.0
# 1596     11.0             0.510       0.75  0.99574                  40.0
# 1597     10.2             0.645       0.71  0.99547                  44.0
# 1598     11.0             0.310       0.66  0.99549                  42.0
#
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# ...

# %%
## SelectKBest

# %%
path=r"C:\Users\Hp\Documents\NareshIT\Data_Files\winequality_red.csv"

# %%
df=pd.read_csv(path)

# %%
X=df.drop('quality',axis=1)
y=df['quality']

# %%
from sklearn.feature_selection import SelectKBest

# %%
sb = SelectKBest(k=5)
sb
# Out:
# SelectKBest(k=5)

# %%
d=sb.fit_transform(X,y)

# %%
pd.DataFrame(d)
# Out:
#           0     1     2     3     4
# 0     0.700  0.00  34.0  0.56   9.4
# 1     0.880  0.00  67.0  0.68   9.8
# 2     0.760  0.04  54.0  0.65   9.8
# 3     0.280  0.56  60.0  0.58   9.8
# 4     0.700  0.00  34.0  0.56   9.4
# ...     ...   ...   ...   ...   ...
# 1594  0.600  0.08  44.0  0.58  10.5
# 1595  0.550  0.10  51.0  0.76  11.2
# 1596  0.510  0.13  40.0  0.75  11.0
# 1597  0.645  0.12  44.0  0.71  10.2
# 1598  0.310  0.47  42.0  0.66  11.0
#
# [1599 rows x 5 columns]

# %%
from sklearn.feature_selection import SelectKBest, f_classif

selector = SelectKBest(score_func=f_classif, k=5)
X_new = selector.fit_transform(X, y)

# %%
X_new
# Out:
# array([[7.00e-01, 0.00e+00, 3.40e+01, 5.60e-01, 9.40e+00],
#        [8.80e-01, 0.00e+00, 6.70e+01, 6.80e-01, 9.80e+00],
#        [7.60e-01, 4.00e-02, 5.40e+01, 6.50e-01, 9.80e+00],
#        ...,
#        [5.10e-01, 1.30e-01, 4.00e+01, 7.50e-01, 1.10e+01],
#        [6.45e-01, 1.20e-01, 4.40e+01, 7.10e-01, 1.02e+01],
#        [3.10e-01, 4.70e-01, 4.20e+01, 6.60e-01, 1.10e+01]])

# %%
selected_columns = X.columns[selector.get_support()]
selected_columns
# Out:
# Index(['volatile acidity', 'citric acid', 'total sulfur dioxide', 'sulphates',
#        'alcohol'],
#       dtype='object')

# %%
X_new_df = pd.DataFrame(X_new, columns=selected_columns)
print(X_new_df.head())
# Out:
#    volatile acidity  citric acid  total sulfur dioxide  sulphates  alcohol
# 0              0.70         0.00                  34.0       0.56      9.4
# 1              0.88         0.00                  67.0       0.68      9.8
# 2              0.76         0.04                  54.0       0.65      9.8
# 3              0.28         0.56                  60.0       0.58      9.8
# 4              0.70         0.00                  34.0       0.56      9.4

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
np.var(df['residual sugar'])
# Out:
# 1.9866539202699018

# %%
import numpy as np

# %%
for i in df.columns.tolist():
    print(i,":",np.var(df[i]))
# Out:
# fixed acidity : 3.0295205688671296
# volatile acidity : 0.03204232613332036
# citric acid : 0.037923751124940605
# residual sugar : 1.9866539202699018
# chlorides : 0.0022137573233114395
# free sulfur dioxide : 109.3464567637451
# total sulfur dioxide : 1081.4256355891553
# density : 3.559801792630711e-06
# pH : 0.023820274241131745
# sulphates : 0.028714647013983425
# alcohol : 1.1349371715080778
# quality : 0.6517605398308234

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
for col in X.columns:
    corr = np.corrcoef(X[col], y)[0,1]
    print(col, ":", corr)
# Out:
# fixed acidity : 0.1240516491132243
# volatile acidity : -0.39055778026400734
# citric acid : 0.22637251431804142
# residual sugar : 0.013731637340066277
# chlorides : -0.12890655993005273
# free sulfur dioxide : -0.05065605724427633
# total sulfur dioxide : -0.18510028892653785
# density : -0.17491922778334884
# pH : -0.05773139120538215
# sulphates : 0.2513970790692614
# alcohol : 0.4761663239995366

# %%
X_new_df.columns.tolist()
# Out:
# ['volatile acidity',
#  'citric acid',
#  'total sulfur dioxide',
#  'sulphates',
#  'alcohol']

# %%
df.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
for i in df.columns.tolist():
    print(i,":",np.var(df[i])/np.var(y))
# Out:
# fixed acidity : 4.64821108938798
# volatile acidity : 0.0491627279884688
# citric acid : 0.05818663267767702
# residual sugar : 3.048134704174596
# chlorides : 0.0033965807808586596
# free sulfur dioxide : 167.77090676911493
# total sulfur dioxide : 1659.2376639890772
# density : 5.4618246657809686e-06
# pH : 0.0365475857855935
# sulphates : 0.04405705049501286
# alcohol : 1.741340725847981
# quality : 1.0

# %%
from sklearn.feature_selection import f_classif

f_scores, p_values = f_classif(X, y)

for name, score in zip(X.columns, f_scores):
    print(name, ":", score)
# Out:
# fixed acidity : 6.283081158220591
# volatile acidity : 60.91399283161205
# citric acid : 19.690664466199774
# residual sugar : 1.053373577852009
# chlorides : 6.035638592358431
# free sulfur dioxide : 4.754233103987809
# total sulfur dioxide : 25.478509518264293
# density : 13.39635690052998
# pH : 4.341764303187651
# sulphates : 22.273376089595967
# alcohol : 115.8547974659645
